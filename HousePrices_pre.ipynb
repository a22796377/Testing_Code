# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

import matplotlib
import sklearn
import scipy
import numpy
import sys

print('matplotlib: {}'.format(matplotlib.__version__))
print('sklearn: {}'.format(sklearn.__version__))
print('scipy: {}'.format(scipy.__version__))
print('seaborn: {}'.format(sns.__version__))
print('pandas: {}'.format(pd.__version__))
print('numpy: {}'.format(np.__version__))
print('Python: {}'.format(sys.version))

sns.set(color_codes=True)
plt.style.available
# %precision 2
# Out:
# matplotlib: 3.3.2
# sklearn: 0.23.2
# scipy: 1.5.2
# seaborn: 0.11.0
# pandas: 1.1.3
# numpy: 1.19.4
# Python: 3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]
# '%.2f'

# %%
#pd.set_option('display.height', 1000)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
# import Dataset
import pandas as pd

train = pd.read_csv('./train.csv')  # import training data
test= pd.read_csv('./test.csv')     # import testing data

# %%
print(type(train), type(test))  
print(train.shape, test.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'> <class 'pandas.core.frame.DataFrame'>
# (60000, 235) (10000, 234)

# %%
train.describe() # Training data count, mea, std, min, max, 25%, 50%, 75%
# Out:
#        building_material          city        txn_dt   total_floor  building_type  building_use  building_complete_dt   parking_way  parking_area  parking_price     txn_floor     land_area  building_area          town           lat           lon  village_income_median  town_population     town_area  town_population_density      doc_rate   master_rate  bachelor_rate  jobschool_rate  highschool_rate   junior_rate  elementary_rate     born_rate    death_rate  marriage_rate  divorce_rate       village          N_50         N_500        N_1000        N_5000       N_10000          I_10         I_50   I_index_50         I_100         I_250         I_500   I_index_500        I_1000  I_index_1000        I_5000  I_index_5000       I_10000  I_index_10000         I_MIN         II_10         II_50   II_index_50        II_100        II_250        II_500  II_index_500       II_1000  II_index_1000       II_5000  II_index_5000      II_10000  II_index_10000        II_MIN        III_10        III_50  \
# ...

# %% [markdown]
# # Checking data

# %%
train.isnull().sum() # missing value count
# Out:
# building_id                    0
# building_material              0
# city                           0
# txn_dt                         0
# total_floor                    0
# building_type                  0
# building_use                   0
# building_complete_dt           0
# parking_way                    0
# parking_area               56897
# parking_price              46065
# txn_floor                  15902
# land_area                      0
# building_area                  0
# town                           0
# lat                            0
# lon                            0
# village_income_median       1142
# town_population                0
# town_area                      0
# town_population_density        0
# doc_rate                       0
# master_rate                    0
# bachelor_rate                  0
# jobschool_rate                 0
# highschool_rate                0
# junior_rate                    0
# elementary_rate                0
# ...

# %%
check_nan = (train.isnull().sum()/train.isnull().count()).sort_values(ascending=False) * 100
check_nan
# Out:
# parking_area               94.828333
# parking_price              76.775000
# txn_floor                  26.503333
# village_income_median       1.903333
# total_price                 0.000000
# III_MIN                     0.000000
# III_index_5000              0.000000
# III_10000                   0.000000
# III_index_10000             0.000000
# IV_10                       0.000000
# IV_50                       0.000000
# IV_index_50                 0.000000
# IV_100                      0.000000
# IV_250                      0.000000
# IV_500                      0.000000
# IV_index_500                0.000000
# III_5000                    0.000000
# III_1000                    0.000000
# III_index_1000              0.000000
# IV_index_1000               0.000000
# III_index_500               0.000000
# III_500                     0.000000
# III_250                     0.000000
# III_100                     0.000000
# III_index_50                0.000000
# ...

# %%
train['parking_area'].unique()   # parking_area distinct value
# Out:
# array([     nan, 7.18e+00, 3.10e+00, 2.09e+01, 4.39e+00, 7.91e+00,
#        5.76e+00, 6.46e+00, 1.75e+01, 1.90e+00, 5.07e+00, 8.20e-01,
#        3.74e+00, 1.34e+00, 1.33e+01, 2.63e+01, 1.17e+01, 8.65e+00,
#        2.49e+00, 1.50e+01, 1.66e+01, 1.41e+01, 1.09e+01, 1.58e+01,
#        1.92e+01, 1.25e+01, 9.41e+00, 2.44e+01, 1.02e+01, 2.18e+01,
#        2.99e+01, 3.54e-01, 2.81e+01, 1.83e+01, 9.02e+01, 4.74e+01,
#        2.00e+01, 2.27e+01, 2.53e+01, 4.04e+01, 0.00e+00, 2.90e+01,
#        3.27e+01, 3.09e+01, 3.65e+01, 2.36e+01, 3.75e+01, 4.24e+01,
#        2.72e+01, 3.46e+01, 6.18e+01, 4.14e+01, 4.44e+01, 8.24e+01,
#        3.37e+01, 3.56e+01, 9.67e+02, 8.35e+01, 5.15e+02, 8.46e+01,
#        5.45e+01, 3.18e+01])

# %%
train["parking_area"].value_counts() # parking_area distinct value count
# Out:
# 6.462491      349
# 5.758023      310
# 5.068286      301
# 4.394560      281
# 3.738412      210
# 7.180619      205
# 3.101806      191
# 2.487288      159
# 7.911500      146
# 1.898314      138
# 1.339884      107
# 8.654350       75
# 0.820013       70
# 10.173320      65
# 9.408490       56
# 11.732982      47
# 13.329711      46
# 10.948309      41
# 14.960540      34
# 12.526912      32
# 14.141028      32
# 0.354220       24
# 16.622993      20
# 15.787953      19
# 19.171448      16
# 17.465409      15
# 18.314967      13
# 26.250635       8
# 22.662740       7
# 29.926274       7
# 21.780470       6
# 23.551037       6
# 20.904384       6
# 0.000000        6
# 24.445211       5
# 28.999556       5
# 32.736202       5
# 40.432080       5
# 20.034651       3
# 33.682452       3
# 42.398789       3
# 25.345121       2
# 37.513183       2
# 27.161624       2
# 35.588834       2
# 36.548801       2
# 34.633358       2
# 30.858020       1
# 41.413400       1
# 83.497319       1
# ...

# %%
train['parking_area'] = train['parking_area'].fillna(0)
#fill up missing 'parking_area' with 0

# %%
train["parking_area"].value_counts()  # parking_area distinct value count
# Out:
# 0.000000      56903
# 6.462491        349
# 5.758023        310
# 5.068286        301
# 4.394560        281
# 3.738412        210
# 7.180619        205
# 3.101806        191
# 2.487288        159
# 7.911500        146
# 1.898314        138
# 1.339884        107
# 8.654350         75
# 0.820013         70
# 10.173320        65
# 9.408490         56
# 11.732982        47
# 13.329711        46
# 10.948309        41
# 14.960540        34
# 12.526912        32
# 14.141028        32
# 0.354220         24
# 16.622993        20
# 15.787953        19
# 19.171448        16
# 17.465409        15
# 18.314967        13
# 26.250635         8
# 29.926274         7
# 22.662740         7
# 21.780470         6
# 23.551037         6
# 20.904384         6
# 24.445211         5
# 28.999556         5
# 32.736202         5
# 40.432080         5
# 20.034651         3
# 33.682452         3
# 42.398789         3
# 25.345121         2
# 37.513183         2
# 27.161624         2
# 35.588834         2
# ...

# %%
train['parking_price'].unique()   # parking_price distinct value
# Out:
# array([     nan, 8.11e+04, 6.15e+04, 6.72e+03, 6.78e+04, 4.95e+04,
#        5.54e+04, 1.93e+04, 1.10e+05, 8.24e+03, 7.44e+04, 1.34e+05,
#        2.36e+04, 3.84e+04, 4.38e+04, 1.16e+04, 1.59e+05, 3.32e+04,
#        2.83e+04, 1.53e+04, 3.57e+04, 9.52e+04, 2.73e+05, 1.76e+05,
#        2.23e+05, 1.85e+03, 1.34e+04, 2.14e+04, 0.00e+00, 1.14e+05,
#        5.32e+03, 5.24e+04, 9.28e+04, 3.07e+04, 2.59e+04, 4.66e+04,
#        3.27e+05, 9.85e+03, 1.72e+04, 4.08e+03, 1.06e+05, 5.84e+04,
#        1.18e+05, 4.03e+03, 1.07e+05, 1.69e+05, 6.46e+04, 7.77e+04,
#        1.60e+03, 4.10e+04, 2.73e+04, 1.22e+03, 2.25e+04, 4.24e+04,
#        2.87e+03, 1.38e+05, 7.46e+02, 3.01e+01, 1.84e+03, 7.21e+04,
#        8.81e+04, 3.38e+03, 2.43e+03, 1.03e+05, 2.19e+04, 2.43e+05,
#        9.70e+05, 1.62e+04, 3.47e+04, 7.11e+04, 1.22e+05, 1.55e+05,
#        9.38e+04, 8.60e+04, 2.27e+04, 1.09e+04, 8.46e+04, 1.95e+05,
#        8.00e+03, 2.41e+03, 2.57e+05, 1.42e+05, 1.08e+05, 4.33e+03,
# ...

# %%
train["parking_price"].value_counts() # parking_price distinct value count
# Out:
# 3.318636e+04    2054
# 4.379195e+04    1891
# 6.148857e+04    1537
# 4.946152e+04     841
# 2.363521e+04     706
# 3.836347e+04     669
# 1.929095e+04     532
# 9.524150e+04     525
# 6.783066e+04     511
# 1.337292e+05     503
# 1.525905e+04     480
# 1.156360e+04     455
# 8.113889e+04     452
# 2.827238e+04     380
# 8.235554e+03     348
# 5.536309e+04     277
# 1.100993e+05     185
# 5.316931e+03     147
# 6.721823e+03     142
# 2.230936e+05     132
# 1.764660e+05     117
# 7.438278e+04      96
# 9.851351e+03      96
# 2.591826e+04      94
# 2.142534e+04      78
# 3.069567e+04      57
# 1.723458e+04      57
# 1.178006e+05      53
# 1.336753e+04      53
# 4.104696e+04      51
# 4.659719e+04      45
# 5.238383e+04      40
# 2.733335e+05      37
# 3.574279e+04      32
# 4.029270e+03      24
# 0.000000e+00      18
# 2.869632e+03      17
# 1.588865e+05      16
# 7.773569e+04      13
# 6.463297e+04      12
# 5.839831e+04       9
# 8.809349e+04       8
# 7.108086e+04       7
# ...

# %%
train['parking_price'] = train['parking_price'].fillna(0)
#fill up 'parking_price' with 0

# %%
train["parking_price"].value_counts() # parking price distinct value count
# Out:
# 0.000000e+00    46083
# 3.318636e+04     2054
# 4.379195e+04     1891
# 6.148857e+04     1537
# 4.946152e+04      841
# 2.363521e+04      706
# 3.836347e+04      669
# 1.929095e+04      532
# 9.524150e+04      525
# 6.783066e+04      511
# 1.337292e+05      503
# 1.525905e+04      480
# 1.156360e+04      455
# 8.113889e+04      452
# 2.827238e+04      380
# 8.235554e+03      348
# 5.536309e+04      277
# 1.100993e+05      185
# 5.316931e+03      147
# 6.721823e+03      142
# 2.230936e+05      132
# 1.764660e+05      117
# 7.438278e+04       96
# 9.851351e+03       96
# 2.591826e+04       94
# 2.142534e+04       78
# 1.723458e+04       57
# 3.069567e+04       57
# 1.336753e+04       53
# 1.178006e+05       53
# 4.104696e+04       51
# 4.659719e+04       45
# 5.238383e+04       40
# 2.733335e+05       37
# 3.574279e+04       32
# 4.029270e+03       24
# 2.869632e+03       17
# 1.588865e+05       16
# 7.773569e+04       13
# 6.463297e+04       12
# 5.839831e+04        9
# ...

# %%
#descriptive statistics summary
train['total_price'].describe() # saleprice count mean std...
# Out:
# count    6.000000e+04
# mean     1.293727e+07
# std      5.522463e+07
# min      2.261495e+05
# 25%      2.433114e+06
# 50%      5.240482e+06
# 75%      1.123932e+07
# max      5.088279e+09
# Name: total_price, dtype: float64

# %%
print(len(train[train['total_price']>1000000])) # saleprice larger than 1M
print(len(train[train['total_price']>5000000])) # saleprice larger than 5M
print(len(train[train['total_price']>10000000])) # saleprice larger than 10M
print(len(train[train['total_price']>100000000])) # saleprice larger than 100M
# train[train['total_price']>100000000]
# Out:
# 55917
# 31073
# 16950
# 743

# %%
#histogram
sns.distplot(train['total_price']); # saleprice skew
# Out:
# C:\Users\a2279\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# skewness and kurtosis :
#  skewness = 3 * (mean - median) / std ==> positive mean right skewness

print("Skewness: %.2f" % train['total_price'].skew())
print("Kurtosis: %f" % train['total_price'].kurt())
# Out:
# Skewness: 40.18
# Kurtosis: 2592.965135

# %% [markdown]
# # Relationship with numerical variables

# %%
# histograms
train.hist(figsize=(15,20)); # all numerical variables in histograms, check the similarity with total_price
#plt.figure();
train.head(4)
# Out:
#         building_id  building_material  city  txn_dt  total_floor  building_type  building_use  building_complete_dt  parking_way  parking_area  parking_price  txn_floor  land_area  building_area  town    lat     lon  village_income_median  town_population  town_area  town_population_density  doc_rate  master_rate  bachelor_rate  jobschool_rate  highschool_rate  junior_rate  elementary_rate  born_rate  death_rate  marriage_rate  divorce_rate  village  N_50  N_500  N_1000  N_5000  N_10000  I_10  I_50  I_index_50  I_100  I_250  I_500  I_index_500  I_1000  I_index_1000  I_5000  I_index_5000  I_10000  I_index_10000       I_MIN  II_10  II_50  II_index_50  II_100  II_250  II_500  II_index_500  II_1000  II_index_1000  II_5000  II_index_5000  II_10000  II_index_10000      II_MIN  III_10  III_50  III_index_50  III_100  III_250  III_500  III_index_500  III_1000  III_index_1000  III_5000  III_index_5000  III_10000  III_index_10000    III_MIN  IV_10  IV_50  IV_index_50  IV_100  IV_250  IV_500  \
# ...

# %%
#correlation matrix
corrmat = train.corr()
f, ax = plt.subplots(figsize=(12, 9))  # without this line, the figure will be too small
sns.heatmap(corrmat, vmax=.8, square=True); #  vmax=.8, smaller value, lighter color means less difference
# square=True, make the plot square
# The lighter color means the higher relationship

# %% [markdown]
# # Checking data

# %%
train_ID=train['building_id'] # Store TRAIN ID
test_ID=test['building_id'] # Store TEST ID
train_ID.head(3)
# Out:
# 0    e3mMIMR3JJqCaXz1
# 1    LgwzgklNvy4QCtq5
# 2    ucIR2NLLsC3T650L
# Name: building_id, dtype: object

# %%
aaa = train.drop('building_id',axis=1, inplace=False) # drop ID withouth replace, inplace=False, axis=1 drop entire IDcolumn
aaa.head(5)
# Out:
#    building_material  city  txn_dt  total_floor  building_type  building_use  building_complete_dt  parking_way  parking_area  parking_price  txn_floor  land_area  building_area  town    lat     lon  village_income_median  town_population  town_area  town_population_density  doc_rate  master_rate  bachelor_rate  jobschool_rate  highschool_rate  junior_rate  elementary_rate  born_rate  death_rate  marriage_rate  divorce_rate  village  N_50  N_500  N_1000  N_5000  N_10000  I_10  I_50  I_index_50  I_100  I_250  I_500  I_index_500  I_1000  I_index_1000  I_5000  I_index_5000  I_10000  I_index_10000       I_MIN  II_10  II_50  II_index_50  II_100  II_250  II_500  II_index_500  II_1000  II_index_1000  II_5000  II_index_5000  II_10000  II_index_10000      II_MIN  III_10  III_50  III_index_50  III_100  III_250  III_500  III_index_500  III_1000  III_index_1000  III_5000  III_index_5000  III_10000  III_index_10000     III_MIN  IV_10  IV_50  IV_index_50  IV_100  IV_250  IV_500  IV_index_500  \
# ...

# %%
train.head(5)
# Out:
#         building_id  building_material  city  txn_dt  total_floor  building_type  building_use  building_complete_dt  parking_way  parking_area  parking_price  txn_floor  land_area  building_area  town    lat     lon  village_income_median  town_population  town_area  town_population_density  doc_rate  master_rate  bachelor_rate  jobschool_rate  highschool_rate  junior_rate  elementary_rate  born_rate  death_rate  marriage_rate  divorce_rate  village  N_50  N_500  N_1000  N_5000  N_10000  I_10  I_50  I_index_50  I_100  I_250  I_500  I_index_500  I_1000  I_index_1000  I_5000  I_index_5000  I_10000  I_index_10000       I_MIN  II_10  II_50  II_index_50  II_100  II_250  II_500  II_index_500  II_1000  II_index_1000  II_5000  II_index_5000  II_10000  II_index_10000      II_MIN  III_10  III_50  III_index_50  III_100  III_250  III_500  III_index_500  III_1000  III_index_1000  III_5000  III_index_5000  III_10000  III_index_10000     III_MIN  IV_10  IV_50  IV_index_50  IV_100  IV_250  IV_500  
# ...

# %%
# Save Id and drop it

#train = pd.read_csv('./house_prices_advanced_regression_techniques/train.csv')
#test= pd.read_csv('./house_prices_advanced_regression_techniques/test.csv')

train_ID=train['building_id']
test_ID=test['building_id']
train.drop('building_id',axis=1, inplace=True) # dopr building_id and inplace
test.drop('building_id',axis=1, inplace=True)
train.head()
# Out:
#    building_material  city  txn_dt  total_floor  building_type  building_use  building_complete_dt  parking_way  parking_area  parking_price  txn_floor  land_area  building_area  town    lat     lon  village_income_median  town_population  town_area  town_population_density  doc_rate  master_rate  bachelor_rate  jobschool_rate  highschool_rate  junior_rate  elementary_rate  born_rate  death_rate  marriage_rate  divorce_rate  village  N_50  N_500  N_1000  N_5000  N_10000  I_10  I_50  I_index_50  I_100  I_250  I_500  I_index_500  I_1000  I_index_1000  I_5000  I_index_5000  I_10000  I_index_10000       I_MIN  II_10  II_50  II_index_50  II_100  II_250  II_500  II_index_500  II_1000  II_index_1000  II_5000  II_index_5000  II_10000  II_index_10000      II_MIN  III_10  III_50  III_index_50  III_100  III_250  III_500  III_index_500  III_1000  III_index_1000  III_5000  III_index_5000  III_10000  III_index_10000     III_MIN  IV_10  IV_50  IV_index_50  IV_100  IV_250  IV_500  IV_index_500  \
# ...

# %%
train_ID.head()
# Out:
# 0    e3mMIMR3JJqCaXz1
# 1    LgwzgklNvy4QCtq5
# 2    ucIR2NLLsC3T650L
# 3    jre1pJhcQj91Kdky
# 4    rQpYpY9nRG7X5mmr
# Name: building_id, dtype: object

# %% [markdown]
# ### Feature selection

# %%
y_train = train.total_price.values

# %%
train.isna().all()
# Out:
# building_material          False
# city                       False
# txn_dt                     False
# total_floor                False
# building_type              False
# building_use               False
# building_complete_dt       False
# parking_way                False
# parking_area               False
# parking_price              False
# txn_floor                  False
# land_area                  False
# building_area              False
# town                       False
# lat                        False
# lon                        False
# village_income_median      False
# town_population            False
# town_area                  False
# town_population_density    False
# doc_rate                   False
# master_rate                False
# bachelor_rate              False
# jobschool_rate             False
# highschool_rate            False
# junior_rate                False
# elementary_rate            False
# born_rate                  False
# ...

# %%
all_data = pd.concat((train, test), sort=False)
all_data.head(5)
# Out:
#    building_material  city  txn_dt  total_floor  building_type  building_use  building_complete_dt  parking_way  parking_area  parking_price  txn_floor  land_area  building_area  town    lat     lon  village_income_median  town_population  town_area  town_population_density  doc_rate  master_rate  bachelor_rate  jobschool_rate  highschool_rate  junior_rate  elementary_rate  born_rate  death_rate  marriage_rate  divorce_rate  village  N_50  N_500  N_1000  N_5000  N_10000  I_10  I_50  I_index_50  I_100  I_250  I_500  I_index_500  I_1000  I_index_1000  I_5000  I_index_5000  I_10000  I_index_10000       I_MIN  II_10  II_50  II_index_50  II_100  II_250  II_500  II_index_500  II_1000  II_index_1000  II_5000  II_index_5000  II_10000  II_index_10000      II_MIN  III_10  III_50  III_index_50  III_100  III_250  III_500  III_index_500  III_1000  III_index_1000  III_5000  III_index_5000  III_10000  III_index_10000     III_MIN  IV_10  IV_50  IV_index_50  IV_100  IV_250  IV_500  IV_index_500  \
# ...

# %% [markdown]
# # Model Deployment

# %%
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC
from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import confusion_matrix
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score
import xgboost as xgb

# %%
# Validation function
# Since cross_val_score doesn't include the shuffle, we add another line instead of shuffle
n_folds = 5

def mse_cv(model):
    kf = KFold(n_folds, shuffle=True, random_state=42).get_n_splits(train.values)  # separate data into 5
    nmse= np.sqrt(-cross_val_score(model, train.values, y_train, scoring="neg_mean_squared_error", cv = kf, error_score='raise')) # ----?????
    return nmse

# %%
train.values
# Out:
# array([[8.00e+00, 2.10e+01, 1.87e+04, ..., 1.00e+00, 3.45e+01, 6.48e+05],
#        [8.00e+00, 7.00e+00, 1.88e+04, ..., 1.00e+00, 4.01e+01, 3.32e+06],
#        [8.00e+00, 7.00e+00, 1.93e+04, ..., 1.00e+00, 5.45e+01, 9.57e+06],
#        ...,
#        [8.00e+00, 7.00e+00, 1.99e+04, ..., 1.00e+00, 9.48e+01, 1.18e+07],
#        [8.00e+00, 1.30e+01, 2.00e+04, ..., 1.00e+00, 3.31e+01, 1.81e+07],
#        [8.00e+00, 7.00e+00, 2.04e+04, ..., 1.00e+00, 4.75e+01, 8.51e+06]])

# %%
GBoost = GradientBoostingRegressor(n_estimators=3000, learning_rate=0.05,                                   
                                   max_depth=4, max_features='sqrt',
                                   min_samples_leaf=15, min_samples_split=10, 
                                   loss='huber', random_state =5)

score = mse_cv(GBoost)
print("Gradient Boosting score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-1a8c11b5c8a0> in <module>
#       4                                    loss='huber', random_state =5)
#       5
# ----> 6 score = mse_cv(GBoost)
#       7 print("Gradient Boosting score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
#
# <ipython-input-31-a65e721c14c6> in mse_cv(model)
#       5 def mse_cv(model):
#       6     kf = KFold(n_folds, shuffle=True, random_state=42).get_n_splits(train.values)  # 數據切成5份
# ----> 7     nmse= np.sqrt(-cross_val_score(model, train.values, y_train, scoring="neg_mean_squared_error", cv = kf, error_score='raise')) # ----?????
#       8     return nmse
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
# ...

# %%
model_xgb = xgb.XGBRegressor(colsample_bytree=0.4603, gamma=0.0468, 
                             learning_rate=0.05, max_depth=3, 
                             min_child_weight=1.7817, n_estimators=2200,
                             reg_alpha=0.4640, reg_lambda=0.8571,
                             subsample=0.5213, silent=1,
                             random_state =7, nthread = -1)

score = mse_cv(model_xgb)
print("Xgboost score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# [23:18:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [23:20:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [23:21:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
# ...

# %%
class AveragingModels(BaseEstimator, RegressorMixin, TransformerMixin):
    def __init__(self, models):
        self.models = models
        
    # we define clones of the original models to fit the data in 
    def fit(self, X, y):         
        self.models_ = [clone(x) for x in self.models]
        
        # Train cloned base models
        for model in self.models_:
            model.fit(X, y)

        return self
    
    #Now we do the predictions for cloned models and average them
    def predict(self, X):
        predictions = np.column_stack([model.predict(X) for model in self.models_])
        return np.mean(predictions, axis=1)

# %%
'''averaged_models = AveragingModels(models = (ENet, GBoost, lasso))

score = mse_cv(averaged_models)
print(" Averaged base models score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))'''
# Out:
# 'averaged_models = AveragingModels(models = (ENet, GBoost, lasso))\n\nscore = mse_cv(averaged_models)\nprint(" Averaged base models score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))'

# %% [markdown]
# # Ensemble prediction

# %%
class StackingAveragedModels(BaseEstimator, RegressorMixin, TransformerMixin):
    def __init__(self, base_models, meta_model, n_folds=5):
        self.base_models = base_models
        self.meta_model = meta_model
        self.n_folds = n_folds
    # We again fit the data on clones of the original models
    def fit(self, X, y):
        self.base_models_ = [list() for x in self.base_models]
        self.meta_model_ = clone(self.meta_model)  # -----------------------------------------?????
        kfold = KFold(n_splits=self.n_folds, shuffle=True, random_state=156)
        
        # Train cloned base models then create out-of-fold predictions
        # that are needed to train the cloned meta-model
        out_of_fold_predictions = np.zeros((X.shape[0], len(self.base_models)))
        for i, model in enumerate(self.base_models):
            for train_index, holdout_index in kfold.split(X, y):
                instance = clone(model)
                self.base_models_[i].append(instance)
                instance.fit(X[train_index], y[train_index])
                y_pred = instance.predict(X[holdout_index])
                out_of_fold_predictions[holdout_index, i] = y_pred
                
        # Now train the cloned  meta-model using the out-of-fold predictions as new feature
        self.meta_model_.fit(out_of_fold_predictions, y)
        return self
    #Do the predictions of all base models on the test data and use the averaged predictions as 
    #meta-features for the final prediction which is done by the meta-model
    def predict(self, X):
        meta_features = np.column_stack([
            np.column_stack([model.predict(X) for model in base_models]).mean(axis=1)
            for base_models in self.base_models_ ])
        return self.meta_model_.predict(meta_features)

# %%
'''stacked_averaged_models = StackingAveragedModels(base_models = (ENet, GBoost, KRR), meta_model = lasso)

score = mse_cv(stacked_averaged_models)
print("Stacking Averaged models score: {:.4f} ({:.4f})".format(score.mean(), score.std()))'''
# Out:
# 'stacked_averaged_models = StackingAveragedModels(base_models = (ENet, GBoost, KRR), meta_model = lasso)\n\nscore = mse_cv(stacked_averaged_models)\nprint("Stacking Averaged models score: {:.4f} ({:.4f})".format(score.mean(), score.std()))'

# %% [markdown]
# ### Final Training and Prediction

# %%
def rmse(y, y_pred):
    return np.sqrt(mean_squared_error(y, y_pred))

# %%
# Gradient Boosting

GBoost.fit(train, y_train)
GBoost_train_pred = GBoost.predict(train)
GBoost_pred = np.exp(GBoost.predict(test))
#GBoost_pred = np.expm1(GBoost.predict(test))
print(rmse(y_train, GBoost_train_pred))
GBoost_pred.max(), GBoost_pred.min()

# %%
test['total_price']=np.nan

# %%
test.drop('total_price',axis=1)
# Out:
#       building_material  city  txn_dt  total_floor  building_type  building_use  building_complete_dt  parking_way  parking_area  parking_price  txn_floor  land_area  building_area  town    lat     lon  village_income_median  town_population  town_area  town_population_density  doc_rate  master_rate  bachelor_rate  jobschool_rate  highschool_rate  junior_rate  elementary_rate  born_rate  death_rate  marriage_rate  divorce_rate  village  N_50  N_500  N_1000  N_5000  N_10000  I_10  I_50  I_index_50  I_100  I_250  I_500  I_index_500  I_1000  I_index_1000  I_5000  I_index_5000  I_10000  I_index_10000       I_MIN  II_10  II_50  II_index_50  II_100  II_250  II_500  II_index_500  II_1000  II_index_1000  II_5000  II_index_5000  II_10000  II_index_10000      II_MIN  III_10  III_50  III_index_50  III_100  III_250  III_500  III_index_500  III_1000  III_index_1000  III_5000  III_index_5000  III_10000  III_index_10000     III_MIN  IV_10  IV_50  IV_index_50  IV_100  IV_250  IV_500  IV_index_500  \
# ...

# %%
test.head()
# Out:
#    building_material  city  txn_dt  total_floor  building_type  building_use  building_complete_dt  parking_way  parking_area  parking_price  txn_floor  land_area  building_area  town    lat     lon  village_income_median  town_population  town_area  town_population_density  doc_rate  master_rate  bachelor_rate  jobschool_rate  highschool_rate  junior_rate  elementary_rate  born_rate  death_rate  marriage_rate  divorce_rate  village  N_50  N_500  N_1000  N_5000  N_10000  I_10  I_50  I_index_50  I_100  I_250  I_500  I_index_500  I_1000  I_index_1000  I_5000  I_index_5000  I_10000  I_index_10000       I_MIN  II_10  II_50  II_index_50  II_100  II_250  II_500  II_index_500  II_1000  II_index_1000  II_5000  II_index_5000  II_10000  II_index_10000      II_MIN  III_10  III_50  III_index_50  III_100  III_250  III_500  III_index_500  III_1000  III_index_1000  III_5000  III_index_5000  III_10000  III_index_10000     III_MIN  IV_10  IV_50  IV_index_50  IV_100  IV_250  IV_500  IV_index_500  \
# ...

# %%
# XGBoost

model_xgb.fit(train, y_train)
xgb_train_pred = model_xgb.predict(train)
xgb_pred = np.exp(model_xgb.predict(test))
#xgb_pred = np.expm1(model_xgb.predict(test))
print(rmse(y_train, xgb_train_pred))
xgb_pred.max(), xgb_pred.min()
# Out:
# [00:01:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# 791341.5640682647
# <ipython-input-61-49c85f3854dd>:5: RuntimeWarning: overflow encountered in exp
#   xgb_pred = np.exp(model_xgb.predict(test))
# (inf, 0.0)

# %%
# XGBOOST
X_results = pd.DataFrame()
X_results['Id'] = test_ID
X_results['total_price'] = xgb_pred
X_results.to_csv('XGBOOST_LING_03292021.csv',index=False) # index=False to prevent pandas from adding another column in our csv file

# %%
sns.distplot(y_train, fit=stats.norm);
fig = plt.figure()
res = stats.probplot(y_train, plot=plt);

# %%
sns.distplot(xgb_pred, fit=stats.norm);
fig = plt.figure()
res = stats.probplot(xgb_pred, plot=plt);
# Out:
# C:\Users\a2279\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\a2279\anaconda3\lib\site-packages\scipy\stats\stats.py:2848: RuntimeWarning: invalid value encountered in subtract
#   out = np.subtract(pct[1], pct[0])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-67ba8a7b3a51> in <module>
# ----> 1 sns.distplot(xgb_pred, fit=stats.norm);
#       2 fig = plt.figure()
#       3 res = stats.probplot(xgb_pred, plot=plt);
#
# ...
